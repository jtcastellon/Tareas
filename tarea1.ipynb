# %% [markdown]
# # Tarea 1

# %% [markdown]
# #### Profesor: Leo Ferres
# #### Alumno  : José Tomás Castellón
# #### Fecha : 05-05-2021

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Muertes por rango etario : producto10/FallecidosEtario.csv'
#Defunciones de Chile : producto32/Defunciones.csv
#Defunciones por COVID de Chile : producto37/Defunciones.csv o Defunciones_deis.csv

# %% [markdown]
# # AQUI COMIENZA LA TAREA

# %%
qrew = pd.read_csv('https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/output/producto32/Defunciones.csv')
qraw = pd.read_csv('https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/output/producto37/Defunciones.csv')

# %%
qraw.dropna(axis="columns", how="any")
# Out:
#                Publicacion  2020-03-20  2020-03-25  2020-03-26  2020-03-27  \
# 0   Defunciones_2020-06-07           1           1           1           1
# 1   Defunciones_2020-06-08           1           1           1           1
# 2   Defunciones_2020-06-09           1           1           1           1
# 3   Defunciones_2020-06-10           1           1           1           1
# 4   Defunciones_2020-06-11           1           1           1           1
# 5   Defunciones_2020-06-12           1           1           1           1
# 6   Defunciones_2020-06-13           1           1           1           1
# 7   Defunciones_2020-06-14           1           1           1           1
# 8   Defunciones_2020-06-15           1           1           1           1
# 9   Defunciones_2020-06-16           1           1           1           1
# 10  Defunciones_2020-06-17           1           1           1           1
# ...

# %%
vals = list(qraw.columns)[1:-1]
ids = list(qraw.columns)[:1]
vaals = list(qrew.columns)[4:-1]
iids = list(qrew.columns)[:4]

# %%
qdf = pd.melt(qraw, value_vars=vals, id_vars=ids)
qde = pd.melt(qrew, value_vars=vaals, id_vars=iids)

# %%
qdf
qde
# Out:
#               Region  Codigo region       Comuna  Codigo comuna    variable  \
# 0        Antofagasta              2  Antofagasta           2101  2010-01-01
# 1        Antofagasta              2       Calama           2201  2010-01-01
# 2        Antofagasta              2  María Elena           2302  2010-01-01
# 3        Antofagasta              2   Mejillones           2102  2010-01-01
# 4        Antofagasta              2      Ollagüe           2202  2010-01-01
# ...              ...            ...          ...            ...         ...
# 1393827        Ñuble             16  San Ignacio          16108  2021-04-28
# 1393828        Ñuble             16  San Nicolás          16305  2021-04-28
# 1393829        Ñuble             16     Treguaco          16207  2021-04-28
# 1393830        Ñuble             16       Yungay          16109  2021-04-28
# 1393831        Ñuble             16       Ñiquén          16303  2021-04-28
#
#          value
# 0            0
# 1            0
# ...

# %%
qdf['value'].sum()
# Out:
# 199548.0

# %%
qde['value'].sum()
# Out:
# 1197643

# %%
print (len(qdf), len(qraw))
# Out:
# 4480 40

# %%
qde.columns
# Out:
# Index(['Region', 'Codigo region', 'Comuna', 'Codigo comuna', 'variable',
#        'value'],
#       dtype='object')

# %%
qde.columns = ['Region', 'Codigo region', 'Comuna', 'Codigo comuna', 'fecha',
      'muertes']

# %%
qde = qde.dropna()

# %%
qde
# Out:
#               Region  Codigo region       Comuna  Codigo comuna       fecha  \
# 0        Antofagasta              2  Antofagasta           2101  2010-01-01
# 1        Antofagasta              2       Calama           2201  2010-01-01
# 2        Antofagasta              2  María Elena           2302  2010-01-01
# 3        Antofagasta              2   Mejillones           2102  2010-01-01
# 4        Antofagasta              2      Ollagüe           2202  2010-01-01
# ...              ...            ...          ...            ...         ...
# 1393827        Ñuble             16  San Ignacio          16108  2021-04-28
# 1393828        Ñuble             16  San Nicolás          16305  2021-04-28
# 1393829        Ñuble             16     Treguaco          16207  2021-04-28
# 1393830        Ñuble             16       Yungay          16109  2021-04-28
# 1393831        Ñuble             16       Ñiquén          16303  2021-04-28
#
#          muertes
# 0              0
# 1              0
# ...

# %%
type(qde['fecha'][0])
# Out:
# str

# %%
qde['variable'] = pd.to_datetime(qdf['variable'])

# %%
res = qdf
res2 = qde

# %% [markdown]
# ### primer gráfico sobre muertes

# %%
res.plot (x='variable', y=['value'])

# %%
res2.plot (x='fecha', y=['muertes'])

# %% [markdown]
# ### Este es un segundo intento de ver los datos, con otra base de datos del DEIS

# %%
wraw = pd.read_csv('DEFUNCIONES_FUENTE_DEIS_2016_2021_29042021.csv', sep = ';', encoding='latin-1')
wraw['FECHA_DEF'] = pd.to_datetime(wraw['FECHA_DEF'])

# %%
df=pd.DataFrame(wraw)

# %%
df.head()
# Out:
#    ANO_DEF  FECHA_DEF GLOSA_SEXO  EDAD_TIPO  EDAD_CANT  \
# 0     2021 2021-03-24      Mujer          1         82
# 1     2021 2021-02-16     Hombre          1         81
# 2     2021 2021-03-04      Mujer          1         87
# 3     2021 2021-12-03     Hombre          1         89
# 4     2021 2021-03-24     Hombre          1         79
#
#    CODIGO_COMUNA_RESIDENCIA GLOSA_COMUNA_RESIDENCIA   GLOSA_REG_RES DIAG1  \
# 0                      2101             Antofagasta  De Antofagasta  C19X
# 1                     10202                   Ancud    De Los Lagos  C64X
# 2                      7301                  Curicó       Del Maule  K254
# 3                      8112                 Hualpén      Del Bíobío  U071
# 4                      1405                    Pica     De Tarapacá  C33X
#
#   CAPITULO_DIAG1                GLOSA_CAPITULO_DIAG1 CODIGO_GRUPO_DIAG1  \
# 0        C00-D48                Tumores [Neoplasias]            C15-C26
# ...

# %%
df.columns
# Out:
# Index(['ANO_DEF', 'FECHA_DEF', 'GLOSA_SEXO', 'EDAD_TIPO', 'EDAD_CANT',
#        'CODIGO_COMUNA_RESIDENCIA', 'GLOSA_COMUNA_RESIDENCIA', 'GLOSA_REG_RES',
#        'DIAG1', 'CAPITULO_DIAG1', 'GLOSA_CAPITULO_DIAG1', 'CODIGO_GRUPO_DIAG1',
#        'GLOSA_GRUPO_DIAG1', 'CODIGO_CATEGORIA_DIAG1', 'GLOSA_CATEGORIA_DIAG1',
#        'CODIGO_SUBCATEGORIA_DIAG1'],
#       dtype='object')

# %%
df['FECHA_DEF'].value_counts()
# Out:
# 2020-06-14    588
# 2020-06-16    587
# 2020-06-06    586
# 2020-09-06    586
# 2020-10-06    584
#              ...
# 2016-12-03    211
# 2017-12-30    182
# 2016-12-30    163
# 2017-12-29    152
# 2021-04-28     73
# Name: FECHA_DEF, Length: 1945, dtype: int64

# %%
df['FECHA_DEF'].value_counts().sort_index(ascending=True).to_frame()
# Out:
#             FECHA_DEF
# 2016-01-01        306
# 2016-01-02        331
# 2016-01-03        282
# 2016-01-04        235
# 2016-01-05        291
# ...               ...
# 2021-11-04        400
# 2021-12-01        340
# 2021-12-02        374
# 2021-12-03        408
# 2021-12-04        445
#
# [1945 rows x 1 columns]

# %%
df['FECHA_DEF'].value_counts().sort_index(ascending=True).plot(kind='bar')

# %%
fechas = df['FECHA_DEF'].value_counts().sort_index(ascending=True).keys().tolist()
fechasneumo = df2['FECHA_DEF'].value_counts().sort_index(ascending=True).keys().tolist()

# %%
muertes = df['FECHA_DEF'].value_counts().sort_index(ascending=True).tolist()
muertesneumo = df2['FECHA_DEF'].value_counts().sort_index(ascending=True).tolist()

# %%
neumo= wraw[wraw['GLOSA_GRUPO_DIAG1']== 'Influenza [gripe] y neumonía']

# %%
len(neumo)
# Out:
# 21265

# %%
df2=pd.DataFrame(neumo)

# %%
df2.head()
# Out:
#      ANO_DEF  FECHA_DEF GLOSA_SEXO  EDAD_TIPO  EDAD_CANT  \
# 98      2021 2021-02-26     Hombre          1         81
# 113     2021 2021-04-23     Hombre          1         84
# 125     2021 2021-02-23     Hombre          1         78
# 175     2021 2021-01-27     Hombre          1         89
# 266     2021 2021-02-16      Mujer          1         93
#
#      CODIGO_COMUNA_RESIDENCIA GLOSA_COMUNA_RESIDENCIA  \
# 98                      13103             Cerro Navia
# 113                     13124                Pudahuel
# 125                     13401            San Bernardo
# 175                      9206              Los Sauces
# 266                      5601             San Antonio
#
#                  GLOSA_REG_RES DIAG1 CAPITULO_DIAG1  \
# 98   Metropolitana de Santiago  J189        J00-J99
# 113  Metropolitana de Santiago  J181        J00-J99
# 125  Metropolitana de Santiago  J189        J00-J99
# 175            De La Araucanía  J182        J00-J99
# ...

# %%
df2['FECHA_DEF'].value_counts().sort_index(ascending=True).plot(kind='bar')

# %%
plt.plot(fechas,muertes)

# %%
plt.plot(fechas,muertesneumo)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-179-b96ab352d69d> in <module>
# ----> 1 plt.plot(fechas,muertesneumo)
#
# D:\Users\Jose\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# D:\Users\Jose\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
# ...
